# %% [markdown]
# # Funciones Complejas

# %% [markdown]
# ## Traslaciones

# %% [markdown]
# Sea $S = \{z \in \mathbb{C}: a < Re(z) < b ; c < Im(z) < d \}$  un sector rectángular, encuentre la imagen de S bajo la proyección $f(z) = z + z_0$, con $z_0 \in  \mathbb{C}$

# %%
import numpy as np
import matplotlib.pyplot as plt

#Parametros
lado  = 2

#Creando Rectángulo
vertices = np.array([
    [-lado / 2 - 1j * lado / 2, lado / 2 - 1j * lado / 2],
    [-lado / 2 + 1j * lado / 2, lado / 2 + 1j * lado / 2],
])

# Definir la función de traslación compleja f(z) = z + ?
def traslacion(z):
    return z + 2 + 2j

# Aplicar la traslación a los vértices del cuadrado
vertices_trasladados = traslacion(vertices)

# Separar las coordenadas x e y de los vértices trasladados
x_trasladados = np.real(vertices_trasladados)
y_trasladados = np.imag(vertices_trasladados)

#Gráfico del cuadrado original
plt.plot(np.real(vertices), np.imag(vertices), 'b-')
plt.plot(np.append(np.real(vertices), np.real(vertices)[0]), np.append(np.imag(vertices), np.imag(vertices)[0]), 'b-')

# Crear el gráfico del cuadrado trasladado
plt.plot(x_trasladados, y_trasladados, 'r-')
plt.plot(np.append(x_trasladados, x_trasladados[0]), np.append(y_trasladados, y_trasladados[0]), 'r-')

plt.xlabel('Parte Real')
plt.ylabel('Parte Imaginaria')
plt.title('Cuadrado Original (Azul) y Cuadrado Trasladado (Rojo) en el Plano Complejo')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Rotaciones y Dilataciones

# %% [markdown]
# ### Sector Rectangular

# %% [markdown]
# Sea $S = \{z \in \mathbb{C}: a < Re(z) < b ; c < Im(z) < d \}$  un sector rectángular, encuentre la imagen de S bajo la proyección $f(z) = k*z*e^{\theta i}$, con $k \in  \mathbb{C}$ y $ 0 < \theta < 2\pi$

# %%
# Definir el cuadrado centrado en el origen y de lado 2
lado = 2
vertices = np.array([
    [-lado / 2 + 1 - 1j * lado / 2, lado / 2 + 1 - 1j * lado / 2],
    [-lado / 2 + 1 + 1j * lado / 2, lado / 2 + 1 + 1j * lado / 2],
])

# Definir la función de rotación y dilatación compleja
def rotacion_dilatacion(z, angulo, escala):
    return z * np.exp(1j * angulo) * escala + 2 + 1j

# Aplicar la rotación y dilatación a los vértices del cuadrado
rotacion = np.pi / 4  # Ángulo de rotación (θ grados)
escala_dilatacion = 2  # Factor de escala
vertices_transformados = rotacion_dilatacion(vertices, angulo_rotacion, escala_dilatacion)

# Separar las coordenadas x e y de los vértices transformados
x_transformados = np.real(vertices_transformados)
y_transformados = np.imag(vertices_transformados)

# Crear el gráfico del cuadrado original
plt.plot(np.real(vertices), np.imag(vertices), 'b-')
plt.plot(np.append(np.real(vertices), np.real(vertices)[0]), np.append(np.imag(vertices), np.imag(vertices)[0]), 'b-')

# Crear el gráfico del cuadrado transformado
plt.plot(x_transformados, y_transformados, 'r-')
plt.plot(np.append(x_transformados, x_transformados[0]), np.append(y_transformados, y_transformados[0]), 'r-')

plt.xlabel('Parte Real')
plt.ylabel('Parte Imaginaria')
plt.title('Cuadrado Original (Azul) y Cuadrado Transformado (Rojo) en el Plano Complejo')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Sector Circular

# %%
# Crear puntos en un círculo de radio 1 centrado en el origen
angulos = np.linspace(0, 2 * np.pi, 100)  # Ángulos equidistantes
radio = 1
puntos_circulo = radio * np.exp(1j * angulos)

# Definir la función de traslación y dilatación compleja
def traslacion_dilatacion(z, escala):
    return z * escala + 2 + 3j

# Aplicar la rotación y dilatación a los puntos del círculo
escala_dilatacion = 1.5  # Factor de escala
puntos_transformados = traslacion_dilatacion(puntos_circulo, escala_dilatacion)

# Separar las coordenadas x e y de los puntos transformados
x_transformados = np.real(puntos_transformados)
y_transformados = np.imag(puntos_transformados)

# Crear el gráfico del círculo original
plt.plot(np.real(puntos_circulo), np.imag(puntos_circulo), 'b-')

# Crear el gráfico del círculo transformado
plt.plot(x_transformados, y_transformados, 'r-')

plt.xlabel('Parte Real')
plt.ylabel('Parte Imaginaria')
plt.title('Círculo Original (Azul) y Círculo Transformado (Rojo) en el Plano Complejo')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Funcion Cuadratica Compleja: $f(z) = z^2$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir el rectángulo
ancho = 1
altura = 10

# Vértices del rectángulo como números complejos
vertices = np.array([
    -ancho / 2 - altura / 2 * 1j,
    ancho / 2 - altura / 2 * 1j,
    ancho / 2 + altura / 2 * 1j,
    -ancho / 2 + altura / 2 * 1j
])

# Definir la función compleja 
def funcion_compleja(z):
    return z**2

# Número de puntos en cada arista
num_puntos = 100

# Transformar las aristas del rectángulo utilizando np.linspace
aristas_transformadas = []

for i in range(4):
    punto_inicial = vertices[i]
    punto_final = vertices[(i + 1) % 4]
    
    arista = np.linspace(punto_inicial, punto_final, num_puntos)
    arista_transformada = funcion_compleja(arista)
    aristas_transformadas.append(arista_transformada)

# Graficar el rectángulo original
vertices_reales = np.real(vertices)
vertices_imaginarios = np.imag(vertices)
plt.plot(np.append(vertices_reales, vertices_reales[0]), np.append(vertices_imaginarios, vertices_imaginarios[0]), 'b-')

# Graficar las aristas transformadas del rectángulo
for arista_transformada in aristas_transformadas:
    plt.plot(np.real(arista_transformada), np.imag(arista_transformada), 'r-')  # 'r-' para una línea roja sólida

plt.xlabel('Parte Real')
plt.ylabel('Parte Imaginaria')
plt.title('Rectángulo Original (Azul) y Aristas Transformadas bajo $z^2$ (Rojo)')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Funcion Cubica Compleja: $f(z) = z^3$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir el rectángulo
ancho = 1
altura = 10

# Vértices del rectángulo como números complejos
vertices = np.array([
    -ancho / 2 - altura / 2 * 1j,
    ancho / 2 - altura / 2 * 1j,
    ancho / 2 + altura / 2 * 1j,
    -ancho / 2 + altura / 2 * 1j
])

# Definir la función compleja 
def funcion_compleja(z):
    return z**3

# Número de puntos en cada arista
num_puntos = 100

# Transformar las aristas del rectángulo utilizando np.linspace
aristas_transformadas = []

for i in range(4):
    punto_inicial = vertices[i]
    punto_final = vertices[(i + 1) % 4]
    
    arista = np.linspace(punto_inicial, punto_final, num_puntos)
    arista_transformada = funcion_compleja(arista)
    aristas_transformadas.append(arista_transformada)

# Graficar el rectángulo original
vertices_reales = np.real(vertices)
vertices_imaginarios = np.imag(vertices)
plt.plot(np.append(vertices_reales, vertices_reales[0]), np.append(vertices_imaginarios, vertices_imaginarios[0]), 'b-')

# Graficar las aristas transformadas del rectángulo
for arista_transformada in aristas_transformadas:
    plt.plot(np.real(arista_transformada), np.imag(arista_transformada), 'r-')  # 'r-' para una línea roja sólida

plt.xlabel('Parte Real')
plt.ylabel('Parte Imaginaria')
plt.title('Rectángulo Original (Azul) y Aristas Transformadas bajo $z^2$ (Rojo)')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Funcion Compleja $f(z) = \dfrac{1}{z}$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir el rectángulo
ancho = 1
altura = 10

# Vértices del rectángulo como números complejos
vertices = np.array([
    -ancho / 2 - altura / 2 * 1j,
    ancho / 2 - altura / 2 * 1j,
    ancho / 2 + altura / 2 * 1j,
    -ancho / 2 + altura / 2 * 1j
])

# Definir la función compleja 
def funcion_compleja(z):
    return 1/z

# Número de puntos en cada arista
num_puntos = 100

# Transformar las aristas del rectángulo utilizando np.linspace
aristas_transformadas = []

for i in range(4):
    punto_inicial = vertices[i]
    punto_final = vertices[(i + 1) % 4]
    
    arista = np.linspace(punto_inicial, punto_final, num_puntos)
    arista_transformada = funcion_compleja(arista)
    aristas_transformadas.append(arista_transformada)

# Graficar el rectángulo original
vertices_reales = np.real(vertices)
vertices_imaginarios = np.imag(vertices)
plt.plot(np.append(vertices_reales, vertices_reales[0]), np.append(vertices_imaginarios, vertices_imaginarios[0]), 'b-')

# Graficar las aristas transformadas del rectángulo
for arista_transformada in aristas_transformadas:
    plt.plot(np.real(arista_transformada), np.imag(arista_transformada), 'r-')  # 'r-' para una línea roja sólida

plt.xlabel('Parte Real')
plt.ylabel('Parte Imaginaria')
plt.title('Rectángulo Original (Azul) y Aristas Transformadas bajo $z^2$ (Rojo)')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Funcion Cuadratica Compleja: $f(z) = e^z$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir el rectángulo
ancho = 1
altura = 10

# Vértices del rectángulo como números complejos
vertices = np.array([
    -ancho / 2 - altura / 2 * 1j,
    ancho / 2 - altura / 2 * 1j,
    ancho / 2 + altura / 2 * 1j,
    -ancho / 2 + altura / 2 * 1j
])

# Definir la función compleja 
def funcion_compleja(z):
    return np.exp(z)

# Número de puntos en cada arista
num_puntos = 100

# Transformar las aristas del rectángulo utilizando np.linspace
aristas_transformadas = []

for i in range(4):
    punto_inicial = vertices[i]
    punto_final = vertices[(i + 1) % 4]
    
    arista = np.linspace(punto_inicial, punto_final, num_puntos)
    arista_transformada = funcion_compleja(arista)
    aristas_transformadas.append(arista_transformada)

# Graficar el rectángulo original
vertices_reales = np.real(vertices)
vertices_imaginarios = np.imag(vertices)
plt.plot(np.append(vertices_reales, vertices_reales[0]), np.append(vertices_imaginarios, vertices_imaginarios[0]), 'b-')

# Graficar las aristas transformadas del rectángulo
for arista_transformada in aristas_transformadas:
    plt.plot(np.real(arista_transformada), np.imag(arista_transformada), 'r-')  # 'r-' para una línea roja sólida

plt.xlabel('Parte Real')
plt.ylabel('Parte Imaginaria')
plt.title('Rectángulo Original (Azul) y Aristas Transformadas bajo $z^2$ (Rojo)')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Funcion Cuadratica Compleja: $f(z) = log(z)$

# %% [markdown]
# ### Sector Rectangular:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir el rectángulo
ancho = 1
altura = 10

# Vértices del rectángulo como números complejos
vertices = np.array([
    -ancho / 2 - altura / 2 * 1j,
    ancho / 2 - altura / 2 * 1j,
    ancho / 2 + altura / 2 * 1j,
    -ancho / 2 + altura / 2 * 1j
])

# Definir la función compleja 
def funcion_compleja(z):
    return np.log(z)

# Número de puntos en cada arista
num_puntos = 100

# Transformar las aristas del rectángulo utilizando np.linspace
aristas_transformadas = []

for i in range(4):
    punto_inicial = vertices[i]
    punto_final = vertices[(i + 1) % 4]
    
    arista = np.linspace(punto_inicial, punto_final, num_puntos)
    arista_transformada = funcion_compleja(arista)
    aristas_transformadas.append(arista_transformada)

# Graficar el rectángulo original
vertices_reales = np.real(vertices)
vertices_imaginarios = np.imag(vertices)
plt.plot(np.append(vertices_reales, vertices_reales[0]), np.append(vertices_imaginarios, vertices_imaginarios[0]), 'b-')

# Graficar las aristas transformadas del rectángulo
for arista_transformada in aristas_transformadas:
    plt.plot(np.real(arista_transformada), np.imag(arista_transformada), 'r-')  # 'r-' para una línea roja sólida

plt.xlabel('Parte Real')
plt.ylabel('Parte Imaginaria')
plt.title('Rectángulo Original (Azul) y Aristas Transformadas bajo $z^2$ (Rojo)')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Sector Circular:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir el sector circular
radio = 5
angulos = np.linspace(0, 2*np.pi, 100)  # Ángulos desde 0 hasta pi/2
puntos_circulo = radio * np.exp(1j * angulos)

# Definir la función compleja
def funcion_compleja(z):
    return np.log(z)

# Aplicar la función compleja al sector circular
sector_transformado = funcion_compleja(puntos_circulo)

# Graficar el sector circular original
plt.plot(np.real(puntos_circulo), np.imag(puntos_circulo), 'b-')

# Graficar el sector transformado
plt.plot(np.real(sector_transformado), np.imag(sector_transformado), 'r-')

plt.xlabel('Parte Real')
plt.ylabel('Parte Imaginaria')
plt.title('Sector Circular Original (Azul) y Sector Transformado bajo Logaritmo (Rojo)')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------
# <table align="rigth">
#   <tr>
#     <td>  Por Luis Gómez R.</td>
#   </tr>
# </table>
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
